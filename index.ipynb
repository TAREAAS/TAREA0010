# %%
import pandas as pd

linkGit="https://github.com/TAREAAS/TAREA0010/raw/main/CleaningData.ipynb"       #paste link here!

dataRaee=pd.read_html(linkGit)
dataRaee
# Out:
# [   Unnamed: 0                 age
#  0           0            It is:24
#  1           1           It is: 44
#  2           2             It is54
#  3           3            64 it is
#  4           4         I am twenty
#  5           5  The 10th I turn 21
#  6           6   I am 15 years old
#  7           7                 ~20,
#     Unnamed: 0                   0     1
#  0           0               It is  24.0
#  1           1               It is  44.0
#  2           2             It is54   NaN
#  3           3            64 it is   NaN
#  4           4         I am twenty   NaN
#  5           5  The 10th I turn 21   NaN
#  6           6   I am 15 years old   NaN
#  7           7                 ~20   NaN,
#     Unnamed: 0          age
#  0           4  I am twenty,
#     Unnamed: 0     0
#  0           0  24.0
#  1           1  44.0
#  2           2  54.0
#  3           3  64.0
#  4           4   NaN
#  5           5  10.0
#  6           6  15.0
#  7           7  20.0,
# ...
